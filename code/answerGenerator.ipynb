# %%
import pandas as pd
import random

# Вопрос 1: "Как вы оцениваете мероприятие?"
question1 = "Как вы оцениваете мероприятие?"

# Пример ответов
answers1 = [
    "Отлично", "Нормально", "Замечательно", "Могло быть лучше", "Хорошо, но мало", 
    "Великолепно", "Удовлетворительно", "Просто супер", "Ожидал большего", 
    "Организация на высоте", "Скучновато", "Превосходно", "Интересно", 
    "Ожидания оправдались", "Все понравилось", "Круто", "Неплохо", 
    "Разочарован", "Пойдет", "Мероприятие было топ", "В целом хорошо", 
    "Средне", "Никак", "Не понравилось", "Восторг", "Потрясающе", 
    "Хотелось бы больше активности", "Душевно", "Не так уж и плохо", 
    "Супер", "Хорошо", "Было весело", "Прекрасно", "Всё было на высоте!",
    "Хорошо, но могло быть лучше", "Отлично, понравилась организация", 
    "Нормально, но немного затянуто", "Очень понравилось, особенно презентации", 
    "Неплохо, но ожидал большего", "Всё супер, больше бы таких мероприятий", 
    "Мероприятие нормальное, но мало новизны", "Всё понравилось, но было шумно", 
    "Организация на уровне, спасибо", "Довольно скучно, ждал большего", "Круто, всё было классно", 
    "Нормально, но скучные спикеры", "Отличное мероприятие, буду участвовать снова", 
    "Мероприятие понравилось, было полезно", "Интересно, но местами тяжело воспринимать", 
    "Классное мероприятие, особенно понравился финал", 
    "Не очень, скучно было", "Отличная организация, но программа длинновата", 
    "Всё супер, динамично и интересно", "Нормально, но не хватает интерактива", 
    "Отлично, атмосфера потрясающая", "В целом, хорошо, но есть что улучшить", 
    "Неплохо, но не впечатлил контент", "Понравилось, но были мелкие недочеты", 
    "Отлично, всё чётко и по делу", "Скучновато, могло быть живее", 
    "Очень понравилось, организация на высоте", "Местами затянуто, но в целом хорошо", 
    "Было классно, но зал был маленький", "Нормально, но в конце устал", "Отличное мероприятие, я доволен", 
    "Всё супер, узнал много нового", "Немного скучно, но в целом хорошо", "Норм", "Класс", 
    "Откровенно плохо", "Я был разочарован", "Оченьт не понравилось, просто ужас", "Ничего выдающегося",
    "Остался равнодушен"
]

# Генерация 1000 ответов для первого вопроса
answers_list1 = [random.choice(answers1) for _ in range(1000)]

# Создание DataFrame для вопроса 1
df1 = pd.DataFrame(answers_list1, columns=[question1])

# Вопрос 2: "Что вам понравилось в мероприятии?"
question2 = "Что вам понравилось в мероприятии?"

# Пример ответов
answers2 = [
    "Организация", "Доклады", "Креативная атмосфера", "Технические темы", "Профессиональные спикеры", 
    "Интерактив", "Общение", "Нетворкинг", "Идеи", "Знания", "Мастер-классы", "Темы обсуждений", 
    "Вопросы участников", "Формат", "Контент", "Программисты", "Разнообразие тем", "Кейсы", 
    "Панельные дискуссии", "Решение задач", "Зона отдыха", "Работа модераторов", "Задания", 
    "Кофе-брейк", "Музыка", "Локация", "Поддержка организаторов", "Круглые столы", 
    "Работа в командах", "Стартапы", "Викторина", "Игровые зоны", "Атмосфера", 
]

# Генерация 1000 ответов для второго вопроса
answers_list2 = [random.choice(answers2) for _ in range(1000)]

# Создание DataFrame для вопроса 2
df2 = pd.DataFrame(answers_list2, columns=[question2])

question3 = "Что бы вы хотели видеть на фуршете в следующий раз?"

answers3 = [
    "Яблоки", "Водку", "Колу", "Прохладительные напитки", "Сендвичи", "Сыр", "Сыры", "Минералку",
    "Лимонад", "Энергетик", "Энергетики", "Энергос", "Конфеты", "Что-нибудь мясное", "Мясные блюда",
    "Мясо", "Что-то сытное", "Что-то легкое", "Диетические блюда", "Вегетрианскую еду", "Сок", "Соки",
    "Рыбу", "Морепродукты", "Мидий", "Кальмаров", "Фрукты", "Груши", "Апельсины", "Сладкое", "Сладости",
    "Печенье", "Салат", "Холодные блюда", "Сухофрукты", "Чай", "Кофе", "Воду", "Раков", "Бургеры",
    "Вишню", "Черешню", "Молоко"
]

# Генерация 1000 ответов для второго вопроса
answers_list3 = [random.choice(answers3) for _ in range(1000)]

# Создание DataFrame для вопроса 2
df3 = pd.DataFrame(answers_list3, columns=[question3])

question4 = "Что бы вы хотели видеть на фуршете в следующий раз?"

answers4 = [
    "вода", "водка", "мясные блюда", "мясо", "рыба", "суши", "салаты", "соки", "алкоголь", "вино", "шампанское",
    "фрукты", "овощи", "сладости", "десерты", "торты", "чипсы", "кексы", "пирожные", "хлеб", "блины", "шашлыки", 
    "пицца", "гамбургеры", "бутерброды", "сухофрукты", "орехи", "сыр", "колбаса", "пельмени", "мороженое", "смузи", 
    "кофе", "чай", "коктейли", "минеральная вода", "газированная вода", "пироги", "шоколад", "зефир", "мармелад", 
    "картофель фри", "гриль", "сэндвичи", "пастила", "яблоки", "груши", "виноград", "персики", "абрикосы", "сок гранатовый",
    "сок апельсиновый", "мандариновый сок", "ананасовый сок", "выпечка", "торт", "бисквит", "варенье", "джем", "восточные сладости",
    "хумус", "лаваш", "мясо на гриле", "крылышки", "ребрышки", "супы", "борщ", "уха", "окрошка", "холодец", "плов", "курица",
    "индейка", "тирамису", "медовик", "чизкейк", "эклеры", "тарталетки", "роллы", "спагетти", "паста", "картофель", "овощной салат",
    "фруктовый салат", "винегрет", "оливье", "грибы", "баклажаны", "кабачки", "арбузы", "дыни", "йогурты", "творог", "сметана", 
    "красная икра", "черная икра", "рулеты", "фаршированная рыба", "мед", "конфеты", "пряники", "картофельное пюре"

]

# Генерация 1000 ответов для второго вопроса
answers_list4 = [random.choice(answers3) for _ in range(1000)]

# Создание DataFrame для вопроса 2
df4 = pd.DataFrame(answers_list4, columns=[question4])

# Сохранение файлов в формате CSV
#df1.to_csv('../data/reps1.csv', index=False)
#df2.to_csv('../data/reps2.csv', index=False)
#df3.to_csv('../data/reps3.csv', index=False)
df4.to_csv('../data/reps4.csv', index=False)

df1.shape, df2.shape, df3.shape, df4.shape  # проверка количества строк
# Out:
# ((1000, 1), (1000, 1), (1000, 1))
